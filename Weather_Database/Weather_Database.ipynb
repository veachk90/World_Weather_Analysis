# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 763

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
            
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_name = city_weather["name"]
        description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y=%m-%d %H:%M:%S')

        # Append the city information into the city_data list
        city_data.append({"City": city_name,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": description})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | ilulissat
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | bowen
# Processing Record 5 of Set 1 | cherskiy
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | carnarvon
# Processing Record 8 of Set 1 | sao felix do xingu
# Processing Record 9 of Set 1 | castro
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 1 | ahipara
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | tuktoyaktuk
# Processing Record 15 of Set 1 | tilichiki
# Processing Record 16 of Set 1 | ludvika
# Processing Record 17 of Set 1 | puerto escondido
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | maragogi
# Processing Record 20 of Set 1 | cedar city
# Processing Record 21 of Set 1 | te anau
# Processing Record 22 of Set 1 | tiznit
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | lima
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | dhangadhi
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | havoysund
# Processing Record 30 of Set 1 | cam ranh
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | sabang
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | pec
# Processing Record 36 of Set 1 | naze
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | nybro
# Processing Record 41 of Set 1 | provideniya
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | cabo san lucas
# Processing Record 44 of Set 1 | bambanglipuro
# Processing Record 45 of Set 1 | katsuura
# Processing Record 46 of Set 1 | santa fe
# Processing Record 47 of Set 1 | alofi
# Processing Record 48 of Set 1 | alyangula
# Processing Record 49 of Set 1 | victoria
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | carutapera
# Processing Record 2 of Set 2 | puerto colombia
# Processing Record 3 of Set 2 | touros
# Processing Record 4 of Set 2 | clyde river
# Processing Record 5 of Set 2 | mildura
# Processing Record 6 of Set 2 | zhigansk
# Processing Record 7 of Set 2 | mnogovershinnyy
# Processing Record 8 of Set 2 | novikovo
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | arraial do cabo
# Processing Record 11 of Set 2 | lagoa
# Processing Record 12 of Set 2 | port macquarie
# Processing Record 13 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 2 | husavik
# Processing Record 15 of Set 2 | salalah
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | bardiyah
# Processing Record 18 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 19 of Set 2 | abu samrah
# Processing Record 20 of Set 2 | ribeira grande
# Processing Record 21 of Set 2 | guerrero negro
# Processing Record 22 of Set 2 | alpine
# Processing Record 23 of Set 2 | black river
# Processing Record 24 of Set 2 | pisco
# Processing Record 25 of Set 2 | homer
# Processing Record 26 of Set 2 | hamilton
# Processing Record 27 of Set 2 | punta arenas
# Processing Record 28 of Set 2 | ouadda
# Processing Record 29 of Set 2 | qasigiannguit
# Processing Record 30 of Set 2 | cape town
# Processing Record 31 of Set 2 | martapura
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | nanchang
# Processing Record 34 of Set 2 | saldanha
# Processing Record 35 of Set 2 | mount isa
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | ileza
# Processing Record 38 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 2 | puerto madero
# Processing Record 40 of Set 2 | luderitz
# Processing Record 41 of Set 2 | zhangjiakou
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | kodiak
# Processing Record 44 of Set 2 | araucaria
# Processing Record 45 of Set 2 | dubai
# Processing Record 46 of Set 2 | chokurdakh
# Processing Record 47 of Set 2 | mantua
# Processing Record 48 of Set 2 | jalingo
# Processing Record 49 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 2 | hermanus
# Processing Record 1 of Set 3 | tabas
# Processing Record 2 of Set 3 | lata
# Processing Record 3 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 3 | telfs
# Processing Record 5 of Set 3 | vostok
# Processing Record 6 of Set 3 | havre
# Processing Record 7 of Set 3 | hidalgo
# Processing Record 8 of Set 3 | kruisfontein
# Processing Record 9 of Set 3 | bambous virieux
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | babushkin
# Processing Record 12 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 3 | sainte-anne-des-monts
# Processing Record 14 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 3 | bauchi
# Processing Record 16 of Set 3 | thinadhoo
# Processing Record 17 of Set 3 | russell
# Processing Record 18 of Set 3 | odesskoye
# Processing Record 19 of Set 3 | qaanaaq
# Processing Record 20 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 3 | galle
# Processing Record 22 of Set 3 | athni
# Processing Record 23 of Set 3 | aracuai
# Processing Record 24 of Set 3 | beinamar
# Processing Record 25 of Set 3 | minab
# Processing Record 26 of Set 3 | mayor pablo lagerenza
# Processing Record 27 of Set 3 | mataura
# Processing Record 28 of Set 3 | tasiilaq
# Processing Record 29 of Set 3 | tambura
# Processing Record 30 of Set 3 | coffs harbour
# Processing Record 31 of Set 3 | lebu
# Processing Record 32 of Set 3 | karatau
# Processing Record 33 of Set 3 | faya
# Processing Record 34 of Set 3 | liverpool
# Processing Record 35 of Set 3 | coahuayana
# Processing Record 36 of Set 3 | nikko
# Processing Record 37 of Set 3 | slave lake
# Processing Record 38 of Set 3 | dikson
# Processing Record 39 of Set 3 | souillac
# Processing Record 40 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 3 | severo-kurilsk
# Processing Record 42 of Set 3 | huntington
# Processing Record 43 of Set 3 | coihaique
# Processing Record 44 of Set 3 | muli
# Processing Record 45 of Set 3 | san patricio
# Processing Record 46 of Set 3 | constitucion
# Processing Record 47 of Set 3 | milkovo
# Processing Record 48 of Set 3 | rapar
# Processing Record 49 of Set 3 | saint-philippe
# Processing Record 50 of Set 3 | laguna
# Processing Record 1 of Set 4 | jamestown
# Processing Record 2 of Set 4 | ardakan
# Processing Record 3 of Set 4 | broome
# Processing Record 4 of Set 4 | nazas
# Processing Record 5 of Set 4 | chuy
# Processing Record 6 of Set 4 | zhanaozen
# Processing Record 7 of Set 4 | ostrovnoy
# Processing Record 8 of Set 4 | tarata
# Processing Record 9 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 4 | santa cruz
# Processing Record 11 of Set 4 | jalu
# Processing Record 12 of Set 4 | shkurinskaya
# Processing Record 13 of Set 4 | mozarlandia
# Processing Record 14 of Set 4 | kinsale
# Processing Record 15 of Set 4 | beloha
# Processing Record 16 of Set 4 | avera
# Processing Record 17 of Set 4 | srednekolymsk
# Processing Record 18 of Set 4 | roald
# Processing Record 19 of Set 4 | turbana
# Processing Record 20 of Set 4 | copiapo
# Processing Record 21 of Set 4 | torbay
# Processing Record 22 of Set 4 | nalut
# Processing Record 23 of Set 4 | varna
# Processing Record 24 of Set 4 | roma
# Processing Record 25 of Set 4 | ardistan
# City not found. Skipping...
# Processing Record 26 of Set 4 | pitimbu
# Processing Record 27 of Set 4 | ancud
# Processing Record 28 of Set 4 | teya
# Processing Record 29 of Set 4 | esperance
# Processing Record 30 of Set 4 | bafra
# Processing Record 31 of Set 4 | tutoia
# Processing Record 32 of Set 4 | miles city
# Processing Record 33 of Set 4 | santa cecilia
# Processing Record 34 of Set 4 | mar del plata
# Processing Record 35 of Set 4 | klaksvik
# Processing Record 36 of Set 4 | maningrida
# Processing Record 37 of Set 4 | sitka
# Processing Record 38 of Set 4 | umm lajj
# Processing Record 39 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 40 of Set 4 | khatanga
# Processing Record 41 of Set 4 | baykit
# Processing Record 42 of Set 4 | hami
# Processing Record 43 of Set 4 | noyabrsk
# Processing Record 44 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 4 | pascagoula
# Processing Record 46 of Set 4 | hay river
# Processing Record 47 of Set 4 | saint george
# Processing Record 48 of Set 4 | montabaur
# Processing Record 49 of Set 4 | port hawkesbury
# Processing Record 50 of Set 4 | sistranda
# Processing Record 1 of Set 5 | boa vista
# Processing Record 2 of Set 5 | norman wells
# Processing Record 3 of Set 5 | baruun-urt
# Processing Record 4 of Set 5 | khani
# Processing Record 5 of Set 5 | hambantota
# Processing Record 6 of Set 5 | jaguey grande
# Processing Record 7 of Set 5 | tura
# Processing Record 8 of Set 5 | ixtapa
# Processing Record 9 of Set 5 | kirakira
# Processing Record 10 of Set 5 | fort wellington
# Processing Record 11 of Set 5 | rodeo
# Processing Record 12 of Set 5 | puerto barrios
# Processing Record 13 of Set 5 | lander
# Processing Record 14 of Set 5 | nome
# Processing Record 15 of Set 5 | iskateley
# Processing Record 16 of Set 5 | high level
# Processing Record 17 of Set 5 | governador valadares
# Processing Record 18 of Set 5 | bridlington
# Processing Record 19 of Set 5 | strezhevoy
# Processing Record 20 of Set 5 | willemstad
# Processing Record 21 of Set 5 | nguru
# Processing Record 22 of Set 5 | teguldet
# Processing Record 23 of Set 5 | nikolskoye
# Processing Record 24 of Set 5 | kaitangata
# Processing Record 25 of Set 5 | martinsville
# Processing Record 26 of Set 5 | kokopo
# Processing Record 27 of Set 5 | suslovo
# Processing Record 28 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 5 | zhuzhou
# Processing Record 30 of Set 5 | cayenne
# Processing Record 31 of Set 5 | ponta do sol
# Processing Record 32 of Set 5 | namatanai
# Processing Record 33 of Set 5 | novobirilyussy
# Processing Record 34 of Set 5 | makakilo city
# Processing Record 35 of Set 5 | tiksi
# Processing Record 36 of Set 5 | ambala
# Processing Record 37 of Set 5 | saint-joseph
# Processing Record 38 of Set 5 | monrovia
# Processing Record 39 of Set 5 | arua
# Processing Record 40 of Set 5 | aklavik
# Processing Record 41 of Set 5 | ushtobe
# Processing Record 42 of Set 5 | burnie
# Processing Record 43 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 44 of Set 5 | torbat-e jam
# Processing Record 45 of Set 5 | tolcayuca
# Processing Record 46 of Set 5 | coruripe
# Processing Record 47 of Set 5 | richards bay
# Processing Record 48 of Set 5 | kayerkan
# Processing Record 49 of Set 5 | port hedland
# Processing Record 50 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 6 | narsaq
# Processing Record 2 of Set 6 | aksarayskiy
# Processing Record 3 of Set 6 | calabar
# Processing Record 4 of Set 6 | peniche
# Processing Record 5 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 7 of Set 6 | pangnirtung
# Processing Record 8 of Set 6 | bouillante
# Processing Record 9 of Set 6 | greenwood
# Processing Record 10 of Set 6 | bogashevo
# Processing Record 11 of Set 6 | rocha
# Processing Record 12 of Set 6 | khor
# Processing Record 13 of Set 6 | puerto suarez
# Processing Record 14 of Set 6 | college
# Processing Record 15 of Set 6 | mayo
# Processing Record 16 of Set 6 | ambanja
# Processing Record 17 of Set 6 | turayf
# Processing Record 18 of Set 6 | jiazi
# Processing Record 19 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 20 of Set 6 | haapiti
# Processing Record 21 of Set 6 | babu
# Processing Record 22 of Set 6 | port elizabeth
# Processing Record 23 of Set 6 | longyearbyen
# Processing Record 24 of Set 6 | kieta
# Processing Record 25 of Set 6 | camacupa
# Processing Record 26 of Set 6 | vardo
# Processing Record 27 of Set 6 | okato
# Processing Record 28 of Set 6 | ouagadougou
# Processing Record 29 of Set 6 | namibe
# Processing Record 30 of Set 6 | lac du bonnet
# Processing Record 31 of Set 6 | caravelas
# Processing Record 32 of Set 6 | marv dasht
# City not found. Skipping...
# Processing Record 33 of Set 6 | saint-pierre
# Processing Record 34 of Set 6 | palencia
# Processing Record 35 of Set 6 | neuquen
# Processing Record 36 of Set 6 | guaira
# Processing Record 37 of Set 6 | burica
# City not found. Skipping...
# Processing Record 38 of Set 6 | paamiut
# Processing Record 39 of Set 6 | snasa
# Processing Record 40 of Set 6 | saint anthony
# Processing Record 41 of Set 6 | kpandu
# Processing Record 42 of Set 6 | mecca
# Processing Record 43 of Set 6 | sao filipe
# Processing Record 44 of Set 6 | sinnamary
# Processing Record 45 of Set 6 | mahebourg
# Processing Record 46 of Set 6 | bondoukou
# Processing Record 47 of Set 6 | kyzyl-suu
# Processing Record 48 of Set 6 | divnomorskoye
# Processing Record 49 of Set 6 | asau
# Processing Record 50 of Set 6 | port lincoln
# Processing Record 1 of Set 7 | poum
# Processing Record 2 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 7 | merauke
# Processing Record 4 of Set 7 | bilibino
# Processing Record 5 of Set 7 | mattru
# Processing Record 6 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 7 of Set 7 | yumen
# Processing Record 8 of Set 7 | banon
# Processing Record 9 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 7 | waddan
# Processing Record 11 of Set 7 | taoudenni
# Processing Record 12 of Set 7 | high river
# Processing Record 13 of Set 7 | kupang
# Processing Record 14 of Set 7 | novoagansk
# Processing Record 15 of Set 7 | boguchany
# Processing Record 16 of Set 7 | iuna
# Processing Record 17 of Set 7 | lompoc
# Processing Record 18 of Set 7 | port hardy
# Processing Record 19 of Set 7 | leningradskiy
# Processing Record 20 of Set 7 | general roca
# Processing Record 21 of Set 7 | kralendijk
# Processing Record 22 of Set 7 | sulangan
# Processing Record 23 of Set 7 | egvekinot
# Processing Record 24 of Set 7 | reconquista
# Processing Record 25 of Set 7 | coquimbo
# Processing Record 26 of Set 7 | marawi
# Processing Record 27 of Set 7 | pangody
# Processing Record 28 of Set 7 | beringovskiy
# Processing Record 29 of Set 7 | aykhal
# Processing Record 30 of Set 7 | isangel
# Processing Record 31 of Set 7 | komsomolskiy
# Processing Record 32 of Set 7 | half moon bay
# Processing Record 33 of Set 7 | preobrazheniye
# Processing Record 34 of Set 7 | vana-voidu
# City not found. Skipping...
# Processing Record 35 of Set 7 | mana
# Processing Record 36 of Set 7 | whitianga
# Processing Record 37 of Set 7 | sept-iles
# Processing Record 38 of Set 7 | kavieng
# Processing Record 39 of Set 7 | hasaki
# Processing Record 40 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 41 of Set 7 | cascais
# Processing Record 42 of Set 7 | pevek
# Processing Record 43 of Set 7 | flinders
# Processing Record 44 of Set 7 | rawson
# Processing Record 45 of Set 7 | jinxiang
# Processing Record 46 of Set 7 | carndonagh
# Processing Record 47 of Set 7 | eunice
# Processing Record 48 of Set 7 | bintulu
# Processing Record 49 of Set 7 | santa rosa
# Processing Record 50 of Set 7 | totma
# Processing Record 1 of Set 8 | lasa
# Processing Record 2 of Set 8 | goderich
# Processing Record 3 of Set 8 | airai
# Processing Record 4 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 8 | nelson bay
# Processing Record 6 of Set 8 | bengkulu
# Processing Record 7 of Set 8 | ginda
# Processing Record 8 of Set 8 | klamath falls
# Processing Record 9 of Set 8 | upernavik
# Processing Record 10 of Set 8 | urengoy
# Processing Record 11 of Set 8 | krasnoselkup
# Processing Record 12 of Set 8 | fare
# Processing Record 13 of Set 8 | talnakh
# Processing Record 14 of Set 8 | cidreira
# Processing Record 15 of Set 8 | mirnyy
# Processing Record 16 of Set 8 | hirara
# Processing Record 17 of Set 8 | lavrentiya
# Processing Record 18 of Set 8 | sur
# Processing Record 19 of Set 8 | mayumba
# Processing Record 20 of Set 8 | meadow lake
# Processing Record 21 of Set 8 | portland
# Processing Record 22 of Set 8 | lake city
# Processing Record 23 of Set 8 | siocon
# Processing Record 24 of Set 8 | aden
# Processing Record 25 of Set 8 | ajdabiya
# Processing Record 26 of Set 8 | sosenskiy
# Processing Record 27 of Set 8 | rajgarh
# Processing Record 28 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 29 of Set 8 | sivas
# Processing Record 30 of Set 8 | bagdarin
# Processing Record 31 of Set 8 | san ramon
# Processing Record 32 of Set 8 | makarov
# Processing Record 33 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 8 | margate
# Processing Record 35 of Set 8 | aripuana
# Processing Record 36 of Set 8 | borogontsy
# Processing Record 37 of Set 8 | grand gaube
# Processing Record 38 of Set 8 | aksha
# Processing Record 39 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 8 | batagay
# Processing Record 41 of Set 8 | acarau
# Processing Record 42 of Set 8 | hondo
# Processing Record 43 of Set 8 | kathmandu
# Processing Record 44 of Set 8 | khandyga
# Processing Record 45 of Set 8 | new iberia
# Processing Record 46 of Set 8 | cairns
# Processing Record 47 of Set 8 | nianzishan
# Processing Record 48 of Set 8 | vila do maio
# Processing Record 49 of Set 8 | tuatapere
# Processing Record 50 of Set 8 | nurota
# Processing Record 1 of Set 9 | alekseyevskaya
# Processing Record 2 of Set 9 | omsukchan
# Processing Record 3 of Set 9 | wuwei
# Processing Record 4 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 9 | lubao
# Processing Record 6 of Set 9 | antofagasta
# Processing Record 7 of Set 9 | brae
# Processing Record 8 of Set 9 | bumba
# Processing Record 9 of Set 9 | high prairie
# Processing Record 10 of Set 9 | nanortalik
# Processing Record 11 of Set 9 | zhangye
# Processing Record 12 of Set 9 | gat
# Processing Record 13 of Set 9 | nurobod
# Processing Record 14 of Set 9 | bethel
# Processing Record 15 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 9 | chifeng
# Processing Record 17 of Set 9 | kinablangan
# Processing Record 18 of Set 9 | langsa
# Processing Record 19 of Set 9 | ejido
# Processing Record 20 of Set 9 | presidencia roque saenz pena
# Processing Record 21 of Set 9 | tsiroanomandidy
# Processing Record 22 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 23 of Set 9 | port keats
# Processing Record 24 of Set 9 | kaeo
# Processing Record 25 of Set 9 | doha
# Processing Record 26 of Set 9 | nganjuk
# Processing Record 27 of Set 9 | juba
# Processing Record 28 of Set 9 | changping
# Processing Record 29 of Set 9 | salinas
# Processing Record 30 of Set 9 | innisfail
# Processing Record 31 of Set 9 | finschhafen
# Processing Record 32 of Set 9 | hofn
# Processing Record 33 of Set 9 | olafsvik
# Processing Record 34 of Set 9 | nileshwar
# Processing Record 35 of Set 9 | carira
# Processing Record 36 of Set 9 | seoul
# Processing Record 37 of Set 9 | buala
# Processing Record 38 of Set 9 | haicheng
# Processing Record 39 of Set 9 | cabedelo
# Processing Record 40 of Set 9 | atambua
# Processing Record 41 of Set 9 | uribia
# Processing Record 42 of Set 9 | ducheng
# Processing Record 43 of Set 9 | kviteseid
# Processing Record 44 of Set 9 | jombang
# Processing Record 45 of Set 9 | dyurtyuli
# Processing Record 46 of Set 9 | yanggu
# Processing Record 47 of Set 9 | christchurch
# Processing Record 48 of Set 9 | basavakalyan
# Processing Record 49 of Set 9 | kysyl-syr
# Processing Record 50 of Set 9 | naifaru
# Processing Record 1 of Set 10 | manaquiri
# Processing Record 2 of Set 10 | tacuarembo
# Processing Record 3 of Set 10 | maarianhamina
# Processing Record 4 of Set 10 | boundiali
# Processing Record 5 of Set 10 | kimbe
# Processing Record 6 of Set 10 | lingyuan
# Processing Record 7 of Set 10 | codrington
# Processing Record 8 of Set 10 | pacific grove
# Processing Record 9 of Set 10 | juifang
# City not found. Skipping...
# Processing Record 10 of Set 10 | semnan
# Processing Record 11 of Set 10 | bilma
# Processing Record 12 of Set 10 | kudahuvadhoo
# Processing Record 13 of Set 10 | santa cruz cabralia
# Processing Record 14 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 15 of Set 10 | oriximina
# Processing Record 16 of Set 10 | severnyy
# Processing Record 17 of Set 10 | chapais
# Processing Record 18 of Set 10 | quatre cocos
# Processing Record 19 of Set 10 | tenkodogo
# Processing Record 20 of Set 10 | ugoofaaru
# Processing Record 21 of Set 10 | udarnyy
# Processing Record 22 of Set 10 | ahuimanu
# Processing Record 23 of Set 10 | kabompo
# Processing Record 24 of Set 10 | shingu
# Processing Record 25 of Set 10 | andenes
# Processing Record 26 of Set 10 | atar
# Processing Record 27 of Set 10 | morro bay
# Processing Record 28 of Set 10 | narrabri
# Processing Record 29 of Set 10 | northam
# Processing Record 30 of Set 10 | podosinovets
# Processing Record 31 of Set 10 | soubre
# Processing Record 32 of Set 10 | nizwa
# Processing Record 33 of Set 10 | wanning
# Processing Record 34 of Set 10 | nizhniy ufaley
# Processing Record 35 of Set 10 | ucluelet
# Processing Record 36 of Set 10 | banda aceh
# Processing Record 37 of Set 10 | san cristobal
# Processing Record 38 of Set 10 | tashtyp
# Processing Record 39 of Set 10 | zambezi
# Processing Record 40 of Set 10 | mindelo
# Processing Record 41 of Set 10 | mangrol
# Processing Record 42 of Set 10 | san lazaro
# Processing Record 43 of Set 10 | los llanos de aridane
# Processing Record 44 of Set 10 | tual
# Processing Record 45 of Set 10 | lorengau
# Processing Record 46 of Set 10 | strelka
# Processing Record 47 of Set 10 | kragero
# Processing Record 48 of Set 10 | kalnibolotskaya
# Processing Record 49 of Set 10 | mount gambier
# Processing Record 50 of Set 10 | eyrarbakki
# Processing Record 1 of Set 11 | the valley
# Processing Record 2 of Set 11 | caohe
# Processing Record 3 of Set 11 | trofors
# Processing Record 4 of Set 11 | noshiro
# Processing Record 5 of Set 11 | dunedin
# Processing Record 6 of Set 11 | la mata
# Processing Record 7 of Set 11 | mahibadhoo
# Processing Record 8 of Set 11 | khaga
# Processing Record 9 of Set 11 | hokitika
# Processing Record 10 of Set 11 | canto do buriti
# Processing Record 11 of Set 11 | freeport
# Processing Record 12 of Set 11 | flin flon
# Processing Record 13 of Set 11 | donskoye
# Processing Record 14 of Set 11 | morehead
# Processing Record 15 of Set 11 | atlantic beach
# Processing Record 16 of Set 11 | jumla
# Processing Record 17 of Set 11 | usevya
# Processing Record 18 of Set 11 | sao gabriel da cachoeira
# Processing Record 19 of Set 11 | xining
# Processing Record 20 of Set 11 | yefremov
# Processing Record 21 of Set 11 | saint-augustin
# Processing Record 22 of Set 11 | sohag
# Processing Record 23 of Set 11 | vega de alatorre
# Processing Record 24 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 11 | troitskoye
# Processing Record 26 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 27 of Set 11 | radom
# Processing Record 28 of Set 11 | palmer
# Processing Record 29 of Set 11 | gopalpur
# Processing Record 30 of Set 11 | barra do garcas
# Processing Record 31 of Set 11 | arman
# Processing Record 32 of Set 11 | quesnel
# Processing Record 33 of Set 11 | port arthur
# Processing Record 34 of Set 11 | durazno
# Processing Record 35 of Set 11 | cap-aux-meules
# Processing Record 36 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 37 of Set 11 | qaqortoq
# Processing Record 38 of Set 11 | varzea da palma
# Processing Record 39 of Set 11 | shellbrook
# Processing Record 40 of Set 11 | mackay
# Processing Record 41 of Set 11 | honiara
# Processing Record 42 of Set 11 | kiruna
# Processing Record 43 of Set 11 | shintomi
# Processing Record 44 of Set 11 | maridi
# Processing Record 45 of Set 11 | ilo
# Processing Record 46 of Set 11 | daru
# Processing Record 47 of Set 11 | mont-dore
# Processing Record 48 of Set 11 | ayios matthaios
# City not found. Skipping...
# Processing Record 49 of Set 11 | dingle
# Processing Record 50 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 12 | queanbeyan
# Processing Record 2 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 12 | raudeberg
# Processing Record 4 of Set 12 | taunggyi
# Processing Record 5 of Set 12 | kununurra
# Processing Record 6 of Set 12 | dongsheng
# Processing Record 7 of Set 12 | yanam
# Processing Record 8 of Set 12 | almaty
# Processing Record 9 of Set 12 | shimanovsk
# Processing Record 10 of Set 12 | aksu
# Processing Record 11 of Set 12 | aksarka
# Processing Record 12 of Set 12 | dicabisagan
# Processing Record 13 of Set 12 | muzquiz
# City not found. Skipping...
# Processing Record 14 of Set 12 | chany
# Processing Record 15 of Set 12 | tiarei
# Processing Record 16 of Set 12 | kamaishi
# Processing Record 17 of Set 12 | nishihara
# Processing Record 18 of Set 12 | broken hill
# Processing Record 19 of Set 12 | shikhany
# Processing Record 20 of Set 12 | cadillac
# Processing Record 21 of Set 12 | progreso
# Processing Record 22 of Set 12 | fougamou
# Processing Record 23 of Set 12 | vila franca do campo
# Processing Record 24 of Set 12 | tchibanga
# Processing Record 25 of Set 12 | pilar
# Processing Record 26 of Set 12 | neyshabur
# Processing Record 27 of Set 12 | opuwo
# Processing Record 28 of Set 12 | santa vitoria do palmar
# Processing Record 29 of Set 12 | vangaindrano
# Processing Record 30 of Set 12 | matara
# Processing Record 31 of Set 12 | krasnorechenskiy
# Processing Record 32 of Set 12 | mandalgovi
# Processing Record 33 of Set 12 | warrington
# Processing Record 34 of Set 12 | leirvik
# Processing Record 35 of Set 12 | eureka
# Processing Record 36 of Set 12 | ustka
# Processing Record 37 of Set 12 | bathsheba
# Processing Record 38 of Set 12 | lake cowichan
# Processing Record 39 of Set 12 | jishou
# Processing Record 40 of Set 12 | pavino
# Processing Record 41 of Set 12 | bainbridge
# Processing Record 42 of Set 12 | geraldton
# Processing Record 43 of Set 12 | walvis bay
# Processing Record 44 of Set 12 | macamic
# Processing Record 45 of Set 12 | navirai
# Processing Record 46 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 12 | perbaungan
# Processing Record 48 of Set 12 | ulladulla
# Processing Record 49 of Set 12 | ngorongoro
# Processing Record 50 of Set 12 | zhuanghe
# Processing Record 1 of Set 13 | kahului
# Processing Record 2 of Set 13 | ayan
# Processing Record 3 of Set 13 | damietta
# Processing Record 4 of Set 13 | maxixe
# Processing Record 5 of Set 13 | zafra
# Processing Record 6 of Set 13 | tazovskiy
# Processing Record 7 of Set 13 | shu
# Processing Record 8 of Set 13 | grimshaw
# Processing Record 9 of Set 13 | karagay
# Processing Record 10 of Set 13 | sunland park
# Processing Record 11 of Set 13 | iqaluit
# Processing Record 12 of Set 13 | douglas
# Processing Record 13 of Set 13 | ranot
# Processing Record 14 of Set 13 | bin qirdan
# Processing Record 15 of Set 13 | pozo colorado
# Processing Record 16 of Set 13 | ust-maya
# Processing Record 17 of Set 13 | lushunkou
# City not found. Skipping...
# Processing Record 18 of Set 13 | verkhnyaya inta
# Processing Record 19 of Set 13 | hakui
# Processing Record 20 of Set 13 | shimoda
# Processing Record 21 of Set 13 | kharitonovo
# Processing Record 22 of Set 13 | vanavara
# Processing Record 23 of Set 13 | tsabong
# Processing Record 24 of Set 13 | udalo
# City not found. Skipping...
# Processing Record 25 of Set 13 | kastamonu
# Processing Record 26 of Set 13 | padang
# Processing Record 27 of Set 13 | tyukhtet
# Processing Record 28 of Set 13 | angoche
# Processing Record 29 of Set 13 | blackwater
# Processing Record 30 of Set 13 | porto santo
# Processing Record 31 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 13 | gangtok
# Processing Record 33 of Set 13 | san quintin
# Processing Record 34 of Set 13 | puerto madryn
# Processing Record 35 of Set 13 | teplodar
# Processing Record 36 of Set 13 | odweyne
# Processing Record 37 of Set 13 | somerset
# Processing Record 38 of Set 13 | gantt
# Processing Record 39 of Set 13 | vidim
# Processing Record 40 of Set 13 | yar-sale
# Processing Record 41 of Set 13 | gombong
# Processing Record 42 of Set 13 | banjar
# Processing Record 43 of Set 13 | south river
# Processing Record 44 of Set 13 | kalakamati
# Processing Record 45 of Set 13 | nuuk
# Processing Record 46 of Set 13 | felipe carrillo puerto
# Processing Record 47 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 48 of Set 13 | vestbygda
# City not found. Skipping...
# Processing Record 49 of Set 13 | otavi
# Processing Record 50 of Set 13 | eyl
# Processing Record 1 of Set 14 | kuhestan
# City not found. Skipping...
# Processing Record 2 of Set 14 | ust-koksa
# Processing Record 3 of Set 14 | cortez
# Processing Record 4 of Set 14 | hovd
# Processing Record 5 of Set 14 | deh rawud
# City not found. Skipping...
# Processing Record 6 of Set 14 | wawa
# Processing Record 7 of Set 14 | volovo
# Processing Record 8 of Set 14 | san jose
# Processing Record 9 of Set 14 | niquelandia
# Processing Record 10 of Set 14 | santa maria
# Processing Record 11 of Set 14 | cienaga
# Processing Record 12 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 14 | abapo
# Processing Record 14 of Set 14 | ambikapur
# Processing Record 15 of Set 14 | norfolk
# Processing Record 16 of Set 14 | axim
# Processing Record 17 of Set 14 | xuanzhou
# Processing Record 18 of Set 14 | kyshtovka
# Processing Record 19 of Set 14 | liku
# Processing Record 20 of Set 14 | okahandja
# Processing Record 21 of Set 14 | yulara
# Processing Record 22 of Set 14 | timizart
# Processing Record 23 of Set 14 | haines junction
# Processing Record 24 of Set 14 | arlit
# Processing Record 25 of Set 14 | manggar
# Processing Record 26 of Set 14 | acari
# Processing Record 27 of Set 14 | puerto del rosario
# Processing Record 28 of Set 14 | victor harbor
# Processing Record 29 of Set 14 | acapulco
# Processing Record 30 of Set 14 | marsh harbour
# Processing Record 31 of Set 14 | puerto vallarta
# Processing Record 32 of Set 14 | micheweni
# Processing Record 33 of Set 14 | knysna
# Processing Record 34 of Set 14 | korla
# Processing Record 35 of Set 14 | platteville
# Processing Record 36 of Set 14 | badou
# Processing Record 37 of Set 14 | faanui
# Processing Record 38 of Set 14 | biak
# Processing Record 39 of Set 14 | jodhpur
# Processing Record 40 of Set 14 | erdenet
# Processing Record 41 of Set 14 | erenhot
# Processing Record 42 of Set 14 | terre-de-bas
# Processing Record 43 of Set 14 | tromso
# Processing Record 44 of Set 14 | kremenki
# Processing Record 45 of Set 14 | la asuncion
# Processing Record 46 of Set 14 | evensk
# Processing Record 47 of Set 14 | misratah
# Processing Record 48 of Set 14 | mao
# Processing Record 49 of Set 14 | aitape
# Processing Record 50 of Set 14 | chute-aux-outardes
# Processing Record 1 of Set 15 | cachoeira do sul
# Processing Record 2 of Set 15 | tautira
# Processing Record 3 of Set 15 | san borja
# Processing Record 4 of Set 15 | labytnangi
# Processing Record 5 of Set 15 | nabire
# Processing Record 6 of Set 15 | vao
# Processing Record 7 of Set 15 | malakal
# Processing Record 8 of Set 15 | colombia
# Processing Record 9 of Set 15 | walldurn
# Processing Record 10 of Set 15 | voh
# Processing Record 11 of Set 15 | saint-francois
# Processing Record 12 of Set 15 | kidal
# Processing Record 13 of Set 15 | ponta delgada
# Processing Record 14 of Set 15 | praia da vitoria
# Processing Record 15 of Set 15 | turukhansk
# Processing Record 16 of Set 15 | macheng
# Processing Record 17 of Set 15 | marzuq
# Processing Record 18 of Set 15 | aktau
# Processing Record 19 of Set 15 | sorland
# Processing Record 20 of Set 15 | paris
# Processing Record 21 of Set 15 | bucyrus
# Processing Record 22 of Set 15 | santa ana
# Processing Record 23 of Set 15 | jerome
# Processing Record 24 of Set 15 | spring valley
# Processing Record 25 of Set 15 | bo
# City not found. Skipping...
# Processing Record 26 of Set 15 | bonavista
# Processing Record 27 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 15 | sambava
# Processing Record 29 of Set 15 | libreville
# Processing Record 30 of Set 15 | torzhok
# Processing Record 31 of Set 15 | patacamaya
# Processing Record 32 of Set 15 | kharp
# Processing Record 33 of Set 15 | bandarbeyla
# Processing Record 34 of Set 15 | manali
# Processing Record 35 of Set 15 | gravelbourg
# Processing Record 36 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 15 | upington
# Processing Record 38 of Set 15 | tarko-sale
# Processing Record 39 of Set 15 | elko
# Processing Record 40 of Set 15 | fortuna
# Processing Record 41 of Set 15 | kerchevskiy
# Processing Record 42 of Set 15 | solnechnyy
# Processing Record 43 of Set 15 | tahoua
# Processing Record 44 of Set 15 | abra de ilog
# Processing Record 45 of Set 15 | socorro
# Processing Record 46 of Set 15 | mananjary
# Processing Record 47 of Set 15 | nioro
# Processing Record 48 of Set 15 | tiruvottiyur
# City not found. Skipping...
# Processing Record 49 of Set 15 | tokur
# Processing Record 50 of Set 15 | yichang
# Processing Record 1 of Set 16 | kesinga
# Processing Record 2 of Set 16 | pimenta bueno
# Processing Record 3 of Set 16 | witu
# Processing Record 4 of Set 16 | nouadhibou
# Processing Record 5 of Set 16 | stropkov
# Processing Record 6 of Set 16 | nizhnevartovsk
# Processing Record 7 of Set 16 | bubaque
# Processing Record 8 of Set 16 | cap malheureux
# Processing Record 9 of Set 16 | ust-kulom
# Processing Record 10 of Set 16 | gorzow wielkopolski
# Processing Record 11 of Set 16 | san carlos
# Processing Record 12 of Set 16 | paragominas
# Processing Record 13 of Set 16 | jardim
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 707

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hithadhoo  -0.6000   73.0833     82.04        75         100
# 1           Ilulissat  69.2167  -51.1000      9.63        93          83
# 2            Thompson  55.7435  -97.8558      5.16        92          20
# 3               Bowen -20.0167  148.2333     76.48        76          24
# 4            Cherskiy  68.7500  161.3000    -31.02       100          88
# 5        Puerto Ayora  -0.7393  -90.3518     75.16        85          74
# 6           Carnarvon -24.8667  113.6333     70.99        71           0
# 7  São Félix do Xingu  -6.6447  -51.9950     94.80        38          79
# 8              Castro -24.7911  -50.0119     75.85        69          94
# 9               Bluff -46.6000  168.3333     53.10        85          74
#
#    Wind Speed Country                 Date Current Description
# 0       15.64      MV  2022=11-14 16:54:51     overcast clouds
# 1        5.32      GL  2022=11-14 16:54:52       broken clouds
# 2        2.30      CA  2022=11-14 16:54:52          few clouds
# 3        5.82      AU  2022=11-14 16:55:16          few clouds
# 4        4.50      RU  2022=11-14 16:55:16     overcast clouds
# 5        8.01      EC  2022=11-14 16:55:17       broken clouds
# 6       18.12      AU  2022=11-14 16:55:17           clear sky
# 7        3.51      BR  2022=11-14 16:54:11       broken clouds
# 8       11.14      BR  2022=11-14 16:55:17     overcast clouds
# 9       11.07      NZ  2022=11-14 16:55:18       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_names = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", 
                                 "Wind Speed", "Current Description"]].copy()
#new_column_names["Current Description"] = ""

# Recreate the DataFrame by using the new column order
city_data_df = new_column_names

# Display sample data
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Hithadhoo      MV  -0.6000   73.0833     82.04        75
# 1           Ilulissat      GL  69.2167  -51.1000      9.63        93
# 2            Thompson      CA  55.7435  -97.8558      5.16        92
# 3               Bowen      AU -20.0167  148.2333     76.48        76
# 4            Cherskiy      RU  68.7500  161.3000    -31.02       100
# 5        Puerto Ayora      EC  -0.7393  -90.3518     75.16        85
# 6           Carnarvon      AU -24.8667  113.6333     70.99        71
# 7  São Félix do Xingu      BR  -6.6447  -51.9950     94.80        38
# 8              Castro      BR -24.7911  -50.0119     75.85        69
# 9               Bluff      NZ -46.6000  168.3333     53.10        85
#
#    Cloudiness  Wind Speed Current Description
# 0         100       15.64     overcast clouds
# 1          83        5.32       broken clouds
# 2          20        2.30          few clouds
# 3          24        5.82          few clouds
# 4          88        4.50     overcast clouds
# 5          74        8.01       broken clouds
# 6           0       18.12           clear sky
# 7          79        3.51       broken clouds
# 8          94       11.14     overcast clouds
# 9          74       11.07       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
